# %%
from pathlib import Path
import argparse
import json
import math
import os
import random
import signal
import subprocess
import sys
import time

from PIL import Image, ImageOps, ImageFilter
from torch import nn, optim
import torch
import torchvision
import torchvision.transforms as transforms

import lightly
import lightly.models as models
import lightly.loss as loss
import lightly.data as data
from lightly.models.barlowtwins import BarlowTwins
from lightly.models.simclr import SimCLR

from simclr.modules.identity import Identity
import torch.nn.functional as F
from torchmetrics.functional import accuracy

from simclr.modules.transformations import TransformsSimCLR
from PIL import Image, ImageOps, ImageFilter

from tqdm import tqdm

import pytorch_lightning as pl
from pytorch_lightning import Trainer, LightningModule

import resnet

# %%
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, root, split, transform, limit=0):
        r"""
        Args:
            root: Location of the dataset folder, usually it is /dataset
            split: The split you want to used, it should be one of train, val or unlabeled.
            transform: the transform you want to applied to the images.
        """

        self.split = split
        self.transform = transform

        self.image_dir = os.path.join(root, split)
        label_path = os.path.join(root, f"{split}_label_tensor.pt")

        if limit == 0:
            self.num_images = len(os.listdir(self.image_dir))
        else:
            self.num_images = limit

        if os.path.exists(label_path):
            self.labels = torch.load(label_path)
        else:
            self.labels = -1 * torch.ones(self.num_images, dtype=torch.long)

    def __len__(self):
        return self.num_images

    def __getitem__(self, idx):
        idx = int(idx)
        with open(os.path.join(self.image_dir, f"{idx}.png"), 'rb') as f:
            img = Image.open(f).convert('RGB')
            
        if self.transform == None:
            return img, self.labels[idx]            

        return self.transform(img), self.labels[idx], torch.tensor(idx).float()

# %%
class ResNetClassifier(LightningModule):
    def __init__(self):
        super().__init__()
        self.backbone = torchvision.models.resnet34(zero_init_residual=True)
#         self.backbone = resnet.get_custom_resnet34()
        self.backbone.fc = nn.Identity()
#         self.backbone.load_state_dict(model.backbone.state_dict())
        
        self.lastLayer = torch.nn.Sequential(
            torch.nn.Linear(512, 1024),
            torch.nn.ReLU(),
            nn.Dropout(p=0.1),
            torch.nn.Linear(1024, 800),
        )
        
        for layer in self.lastLayer.modules():
           if isinstance(layer, nn.Linear):
                layer.weight.data.normal_(mean=0.0, std=0.01)
                layer.bias.data.zero_()
        
        self.param_groups = [dict(params=self.lastLayer.parameters(), lr=0.01)]
        self.param_groups.append(dict(params=self.backbone.parameters(), lr=0.0001))
        
        self.criterion=torch.nn.CrossEntropyLoss()
        
    def forward(self, x):
        x = self.backbone(x)
        x = self.lastLayer(x)
        return x
    
    def training_step(self, batch, batch_idx):
        data, label, _ = batch
        classProbs = self.forward(data)
        loss = self.criterion(classProbs, label)
        self.log('train_loss', loss)
        return loss
    
    def _evaluate(self, batch, batch_idx, stage=None):
        x, y, _ = batch
        out = self.forward(x)
        logits = F.log_softmax(out, dim=-1)
        loss = F.nll_loss(logits, y)
        preds = torch.argmax(logits, dim=-1)
        acc = accuracy(preds, y)

        if stage:
            self.log(f'{stage}_loss', loss, prog_bar=True)
            self.log(f'{stage}_acc', acc, prog_bar=True)

        return loss, acc
    
    def validation_step(self,batch,batch_idx):
        self._evaluate(batch, batch_idx, 'val')[0]
    
    def configure_optimizers(self):
        optimizer = optim.SGD(self.param_groups, 0, momentum=0.9, weight_decay=1e-5)
        scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, EPOCHS, verbose=True)
        return {'optimizer': optimizer, 'lr_scheduler': scheduler, 'monitor': 'val_loss'}

# %%
checkpointDir = 'barlow-34'

# %%
classifier = ResNetClassifier()

if os.path.isfile('/scratch/vvb238/' + checkpointDir + '/27-classifier.pth'):
    ckpt = torch.load('/scratch/vvb238/' + checkpointDir + '/27-classifier.pth',
                      map_location='cpu')
    classifier.load_state_dict(ckpt)

# %%
unlabeled_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

entireUnlabeledDataset = CustomDataset(root='/dataset', split="unlabeled", transform=unlabeled_transform)
# toBeRankedIndices = torch.tensor([i for i in range(len(entireUnlabeledDataset))])

# %%
classifier = classifier.cuda()
entireUnlabeledDataLoader = torch.utils.data.DataLoader(entireUnlabeledDataset, batch_size=512, 
                                                        shuffle=True, num_workers=4, pin_memory=True)

# %%
allDifferenceInTopTwo, predictedLabels = torch.Tensor(), torch.Tensor()
actualLabels, allIndices, allImageTensors = torch.Tensor(), torch.tensor([]), torch.Tensor()

classifier.eval()
print("\tStarting the evaluation process with unlabeled data")
with torch.no_grad():
    # Going through the left over unlabeled set and collecting the confidence for model predictions
    numOfBatches = len(entireUnlabeledDataset) / entireUnlabeledDataLoader.batch_size
    for idx, batch in tqdm(enumerate(entireUnlabeledDataLoader), total=int(numOfBatches)):
        images, labels, indices = batch

        images = images.cuda()
#             labels = labels.cuda()

        classScores = classifier(images)
        classLogits = F.softmax(classScores, dim=1)

        # Taking the top 2 values in the class prediction for each image
        labelConfidence, predictions = torch.sort(classLogits.data, dim=1, descending=True)
        # And subtracting those values
        differenceInTopTwo = labelConfidence[:, 0] - labelConfidence[:, 1]
        # Sorting based on the subtracted values, this gives the images with most confusion between top two classes
        sortedDifferenceInTopTwo, sortedDifferenceInTopTwoPos = torch.sort(differenceInTopTwo, descending=False)
        # Taking the top 150 of the confusion to avoid memory overload
        topSortedDifferenceInTopTwoPos = sortedDifferenceInTopTwoPos[:150]

        allDifferenceInTopTwo = torch.cat((allDifferenceInTopTwo, differenceInTopTwo[topSortedDifferenceInTopTwoPos].cpu()))
        allIndices = torch.cat((allIndices, indices[topSortedDifferenceInTopTwoPos].cpu()))
        

    print("\tGot the predictions of" , len(entireUnlabeledDataset), " images")

    # Sorting all the predictions based on the confidence scores and the argsort
    allSortedDifferenceInTopTwo, allSortedDifferenceInTopTwoPos = torch.sort(allDifferenceInTopTwo, descending=False)
    print("\tSorted the predictions based on confidence scores")

    # Calculating how many top predictions to retrain the model on
    leastDifferenceInTopTwoPos = allSortedDifferenceInTopTwoPos[:100000]
    print("\tGot the top ", 100000, "confidence indices")


    # Fetching the top confidence's index in original dataset
    topConfidenceIndices = allIndices[leastDifferenceInTopTwoPos]
# Out:
# 	Starting the evaluation process with unlabeled data
#   0%|          | 0/1000 [00:05<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-a376cb3822e4> in <module>
#       7     # Going through the left over unlabeled set and collecting the confidence for model predictions
#       8     numOfBatches = len(entireUnlabeledDataset) / entireUnlabeledDataLoader.batch_size
# ----> 9     for idx, batch in tqdm(enumerate(entireUnlabeledDataLoader), total=int(numOfBatches)):
#      10         images, labels, indices = batch
#      11
#
# /ext3/miniconda3/envs/dev/lib/python3.8/site-packages/tqdm/std.py in __iter__(self)
#    1176
#    1177         try:
# -> 1178             for obj in iterable:
#    1179                 yield obj
#    1180                 # Update and possibly print the progressbar.
#
# /ext3/miniconda3/envs/dev/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     515             if self._sampler_iter is None:
#     516                 self._reset()
# --> 517             data = self._next_data()
#     518             self._num_yielded += 1
#     519             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /ext3/miniconda3/envs/dev/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1180
#    1181             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1182             idx, data = self._get_data()
#    1183             self._tasks_outstanding -= 1
#    1184             if self._dataset_kind == _DatasetKind.Iterable:
#
# /ext3/miniconda3/envs/dev/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1136         elif self._pin_memory:
#    1137             while self._pin_memory_thread.is_alive():
# -> 1138                 success, data = self._try_get_data()
#    1139                 if success:
#    1140                     return data
#
# /ext3/miniconda3/envs/dev/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     984         #   (bool: whether successfully get data, any: data if successful else None)
#     985         try:
# --> 986             data = self._data_queue.get(timeout=timeout)
#     987             return (True, data)
#     988         except Exception as e:
#
# /ext3/miniconda3/envs/dev/lib/python3.8/queue.py in get(self, block, timeout)
#     177                     if remaining <= 0.0:
#     178                         raise Empty
# --> 179                     self.not_empty.wait(remaining)
#     180             item = self._get()
#     181             self.not_full.notify()
#
# /ext3/miniconda3/envs/dev/lib/python3.8/threading.py in wait(self, timeout)
#     304             else:
#     305                 if timeout > 0:
# --> 306                     gotit = waiter.acquire(True, timeout)
#     307                 else:
#     308                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
unlabeledFilteredData = torch.utils.data.Subset(entireUnlabeledDataset, topConfidenceIndices.tolist())
unlabeledFiteredDataLoader = torch.utils.data.DataLoader(unlabeledFilteredData, batch_size=512, shuffle=False, num_workers=4, pin_memory=True)

# %%
allIndices, allImageEncoding = torch.Tensor(), torch.tensor([])

classifier.eval()
print("\tStarting the evaluation process with unlabeled data")
with torch.no_grad():
    # Going through the left over unlabeled set and collecting the confidence for model predictions
    numOfBatches = len(unlabeledFilteredData) / unlabeledFiteredDataLoader.batch_size
    for idx, batch in tqdm(enumerate(unlabeledFiteredDataLoader), total=int(numOfBatches)):
        images, labels, indices = batch

        images = images.cuda()
#             labels = labels.cuda()

        classScores = classifier(images)
        classLogits = F.softmax(classScores, dim=1)

        allImageEncoding = torch.cat((allImageEncoding, classLogits.cpu()))
        allIndices = torch.cat((allIndices, indices.cpu()))
# Out:
# 	Starting the evaluation process with unlabeled data
# 196it [02:00,  1.62it/s]

# %%
from sklearn.cluster import KMeans
import numpy as np

# %%
allImageEncoding = allImageEncoding.numpy()
allIndices = allIndices.numpy()

# %%
allImageEncoding.shape
# Out:
# (100000, 800)

# %%
kmeans = KMeans(n_clusters=800, n_init=5, verbose=1).fit(allImageEncoding)
# Out:
# Initialization complete
# Iteration 0, inertia 2656.10791015625
# Iteration 1, inertia 2190.6669921875
# Iteration 2, inertia 2122.38720703125
# Iteration 3, inertia 2092.43408203125
# Iteration 4, inertia 2075.581298828125
# Iteration 5, inertia 2065.463134765625
# Iteration 6, inertia 2058.611083984375
# Iteration 7, inertia 2053.73681640625
# Iteration 8, inertia 2050.10791015625
# Iteration 9, inertia 2047.1480712890625
# Iteration 10, inertia 2044.8035888671875
# Iteration 11, inertia 2042.8455810546875
# Iteration 12, inertia 2041.1810302734375
# Iteration 13, inertia 2039.7398681640625
# Iteration 14, inertia 2038.52685546875
# Iteration 15, inertia 2037.4541015625
# Iteration 16, inertia 2036.523681640625
# Iteration 17, inertia 2035.7159423828125
# Iteration 18, inertia 2034.9560546875
# Iteration 19, inertia 2034.3880615234375
# Iteration 20, inertia 2033.875
# Iteration 21, inertia 2033.430419921875
# Iteration 22, inertia 2033.055908203125
# Iteration 23, inertia 2032.7059326171875
# Iteration 24, inertia 2032.4219970703125
# Iteration 25, inertia 2032.1507568359375
# Iteration 26, inertia 2031.864501953125
# Iteration 27, inertia 2031.57177734375
# Iteration 28, inertia 2031.3338623046875
# Iteration 29, inertia 2031.12158203125
# Iteration 30, inertia 2030.961669921875
# Iteration 31, inertia 2030.8148193359375
# Iteration 32, inertia 2030.6895751953125
# Iteration 33, inertia 2030.59619140625
# Iteration 34, inertia 2030.5198974609375
# Iteration 35, inertia 2030.4576416015625
# Iteration 36, inertia 2030.38525390625
# Iteration 37, inertia 2030.2926025390625
# Iteration 38, inertia 2030.2294921875
# Iteration 39, inertia 2030.14892578125
# Iteration 40, inertia 2030.094482421875
# Iteration 41, inertia 2030.031005859375
# Iteration 42, inertia 2029.994384765625
# Iteration 43, inertia 2029.9329833984375
# Iteration 44, inertia 2029.875
# Iteration 45, inertia 2029.810302734375
# Iteration 46, inertia 2029.758544921875
# Iteration 47, inertia 2029.7088623046875
# Iteration 48, inertia 2029.633056640625
# Iteration 49, inertia 2029.534423828125
# Iteration 50, inertia 2029.4283447265625
# Iteration 51, inertia 2029.3531494140625
# Iteration 52, inertia 2029.2694091796875
# Iteration 53, inertia 2029.218994140625
# Iteration 54, inertia 2029.1651611328125
# Iteration 55, inertia 2029.12353515625
# Iteration 56, inertia 2029.084228515625
# Iteration 57, inertia 2029.04345703125
# Iteration 58, inertia 2028.9976806640625
# Iteration 59, inertia 2028.965087890625
# Iteration 60, inertia 2028.9290771484375
# Iteration 61, inertia 2028.902587890625
# Iteration 62, inertia 2028.876953125
# Iteration 63, inertia 2028.8477783203125
# Iteration 64, inertia 2028.8076171875
# Iteration 65, inertia 2028.7796630859375
# Iteration 66, inertia 2028.7633056640625
# Iteration 67, inertia 2028.7359619140625
# Iteration 68, inertia 2028.7108154296875
# Iteration 69, inertia 2028.690185546875
# Iteration 70, inertia 2028.6524658203125
# Iteration 71, inertia 2028.6300048828125
# Iteration 72, inertia 2028.60595703125
# Iteration 73, inertia 2028.58544921875
# Iteration 74, inertia 2028.5615234375
# Iteration 75, inertia 2028.5469970703125
# Iteration 76, inertia 2028.52392578125
# Iteration 77, inertia 2028.5125732421875
# Iteration 78, inertia 2028.5069580078125
# Iteration 79, inertia 2028.4964599609375
# Iteration 80, inertia 2028.4886474609375
# Iteration 81, inertia 2028.4754638671875
# Iteration 82, inertia 2028.4705810546875
# Iteration 83, inertia 2028.46337890625
# Iteration 84, inertia 2028.4573974609375
# Iteration 85, inertia 2028.448486328125
# Iteration 86, inertia 2028.4432373046875
# Iteration 87, inertia 2028.43701171875
# Iteration 88, inertia 2028.429443359375
# Iteration 89, inertia 2028.43212890625
# Iteration 90, inertia 2028.4342041015625
# Iteration 91, inertia 2028.42724609375
# Iteration 92, inertia 2028.423583984375
# Iteration 93, inertia 2028.42041015625
# Iteration 94, inertia 2028.41796875
# Iteration 95, inertia 2028.4085693359375
# Iteration 96, inertia 2028.3997802734375
# Iteration 97, inertia 2028.392822265625
# Iteration 98, inertia 2028.3876953125
# Iteration 99, inertia 2028.3851318359375
# Iteration 100, inertia 2028.382080078125
# Iteration 101, inertia 2028.382568359375
# Iteration 102, inertia 2028.3782958984375
# Iteration 103, inertia 2028.366943359375
# Iteration 104, inertia 2028.364990234375
# Iteration 105, inertia 2028.359130859375
# Iteration 106, inertia 2028.3544921875
# Iteration 107, inertia 2028.3521728515625
# Iteration 108, inertia 2028.349853515625
# Iteration 109, inertia 2028.348876953125
# Iteration 110, inertia 2028.348876953125
# Iteration 111, inertia 2028.34814453125
# Iteration 112, inertia 2028.3447265625
# Iteration 113, inertia 2028.3431396484375
# Iteration 114, inertia 2028.3421630859375
# Converged at iteration 114: strict convergence.
# Initialization complete
# Iteration 0, inertia 2666.3759765625
# Iteration 1, inertia 2195.807861328125
# Iteration 2, inertia 2129.22705078125
# Iteration 3, inertia 2100.525634765625
# Iteration 4, inertia 2083.82568359375
# Iteration 5, inertia 2073.0185546875
# Iteration 6, inertia 2065.53466796875
# Iteration 7, inertia 2060.410400390625
# Iteration 8, inertia 2056.649658203125
# Iteration 9, inertia 2053.75
# Iteration 10, inertia 2051.455322265625
# Iteration 11, inertia 2049.5302734375
# Iteration 12, inertia 2047.9273681640625
# Iteration 13, inertia 2046.501953125
# Iteration 14, inertia 2045.2763671875
# Iteration 15, inertia 2044.0906982421875
# Iteration 16, inertia 2043.1431884765625
# Iteration 17, inertia 2042.2105712890625
# Iteration 18, inertia 2041.3568115234375
# Iteration 19, inertia 2040.6356201171875
# Iteration 20, inertia 2040.0155029296875
# Iteration 21, inertia 2039.4593505859375
# Iteration 22, inertia 2038.9993896484375
# Iteration 23, inertia 2038.559326171875
# Iteration 24, inertia 2038.1353759765625
# Iteration 25, inertia 2037.7794189453125
# Iteration 26, inertia 2037.43212890625
# Iteration 27, inertia 2037.0909423828125
# Iteration 28, inertia 2036.7847900390625
# Iteration 29, inertia 2036.515869140625
# Iteration 30, inertia 2036.2239990234375
# Iteration 31, inertia 2036.011474609375
# Iteration 32, inertia 2035.830322265625
# Iteration 33, inertia 2035.644775390625
# Iteration 34, inertia 2035.46435546875
# Iteration 35, inertia 2035.304443359375
# Iteration 36, inertia 2035.1148681640625
# Iteration 37, inertia 2034.90673828125
# Iteration 38, inertia 2034.742919921875
# Iteration 39, inertia 2034.5697021484375
# Iteration 40, inertia 2034.4302978515625
# Iteration 41, inertia 2034.3043212890625
# Iteration 42, inertia 2034.2054443359375
# Iteration 43, inertia 2034.1136474609375
# Iteration 44, inertia 2034.02392578125
# Iteration 45, inertia 2033.949951171875
# Iteration 46, inertia 2033.88916015625
# Iteration 47, inertia 2033.824951171875
# Iteration 48, inertia 2033.7745361328125
# Iteration 49, inertia 2033.71923828125
# Iteration 50, inertia 2033.6661376953125
# Iteration 51, inertia 2033.6285400390625
# Iteration 52, inertia 2033.5892333984375
# Iteration 53, inertia 2033.5650634765625
# Iteration 54, inertia 2033.53955078125
# Iteration 55, inertia 2033.5360107421875
# Iteration 56, inertia 2033.5118408203125
# Iteration 57, inertia 2033.483154296875
# Iteration 58, inertia 2033.450927734375
# Iteration 59, inertia 2033.42626953125
# Iteration 60, inertia 2033.402099609375
# Iteration 61, inertia 2033.379150390625
# Iteration 62, inertia 2033.3701171875
# Iteration 63, inertia 2033.354736328125
# Iteration 64, inertia 2033.3404541015625
# Iteration 65, inertia 2033.3193359375
# Iteration 66, inertia 2033.306640625
# Iteration 67, inertia 2033.294189453125
# Iteration 68, inertia 2033.2845458984375
# Iteration 69, inertia 2033.283935546875
# Iteration 70, inertia 2033.273681640625
# Iteration 71, inertia 2033.2691650390625
# Iteration 72, inertia 2033.26318359375
# Iteration 73, inertia 2033.2586669921875
# Iteration 74, inertia 2033.248291015625
# Iteration 75, inertia 2033.23486328125
# Iteration 76, inertia 2033.2254638671875
# Iteration 77, inertia 2033.2216796875
# Iteration 78, inertia 2033.2161865234375
# Iteration 79, inertia 2033.20849609375
# Iteration 80, inertia 2033.2081298828125
# Iteration 81, inertia 2033.201904296875
# Iteration 82, inertia 2033.1942138671875
# Iteration 83, inertia 2033.186767578125
# Iteration 84, inertia 2033.1787109375
# Iteration 85, inertia 2033.1722412109375
# Iteration 86, inertia 2033.1719970703125
# Iteration 87, inertia 2033.1656494140625
# Iteration 88, inertia 2033.16162109375
# Iteration 89, inertia 2033.1580810546875
# Iteration 90, inertia 2033.15771484375
# Iteration 91, inertia 2033.157958984375
# Converged at iteration 91: strict convergence.
# Initialization complete
# Iteration 0, inertia 2664.36474609375
# Iteration 1, inertia 2189.21728515625
# Iteration 2, inertia 2122.15625
# Iteration 3, inertia 2094.2021484375
# Iteration 4, inertia 2078.084228515625
# Iteration 5, inertia 2067.572509765625
# Iteration 6, inertia 2060.084716796875
# Iteration 7, inertia 2054.739990234375
# Iteration 8, inertia 2050.848388671875
# Iteration 9, inertia 2047.6357421875
# Iteration 10, inertia 2045.139404296875
# Iteration 11, inertia 2043.11181640625
# Iteration 12, inertia 2041.5240478515625
# Iteration 13, inertia 2040.2930908203125
# Iteration 14, inertia 2039.4560546875
# Iteration 15, inertia 2038.7066650390625
# Iteration 16, inertia 2038.059814453125
# Iteration 17, inertia 2037.4375
# Iteration 18, inertia 2036.9256591796875
# Iteration 19, inertia 2036.3992919921875
# Iteration 20, inertia 2035.839111328125
# Iteration 21, inertia 2035.382080078125
# Iteration 22, inertia 2034.9337158203125
# Iteration 23, inertia 2034.5201416015625
# Iteration 24, inertia 2034.0872802734375
# Iteration 25, inertia 2033.64306640625
# Iteration 26, inertia 2033.2659912109375
# Iteration 27, inertia 2032.987548828125
# Iteration 28, inertia 2032.7691650390625
# Iteration 29, inertia 2032.574462890625
# Iteration 30, inertia 2032.3839111328125
# Iteration 31, inertia 2032.2301025390625
# Iteration 32, inertia 2032.059814453125
# Iteration 33, inertia 2031.8876953125
# Iteration 34, inertia 2031.7301025390625
# Iteration 35, inertia 2031.615234375
# Iteration 36, inertia 2031.50537109375
# Iteration 37, inertia 2031.4168701171875
# Iteration 38, inertia 2031.3314208984375
# Iteration 39, inertia 2031.265625
# Iteration 40, inertia 2031.1976318359375
# Iteration 41, inertia 2031.142578125
# Iteration 42, inertia 2031.0823974609375
# Iteration 43, inertia 2031.0224609375
# Iteration 44, inertia 2030.97607421875
# Iteration 45, inertia 2030.9403076171875
# Iteration 46, inertia 2030.8902587890625
# Iteration 47, inertia 2030.8477783203125
# Iteration 48, inertia 2030.8131103515625
# Iteration 49, inertia 2030.789306640625
# Iteration 50, inertia 2030.74609375
# Iteration 51, inertia 2030.723388671875
# Iteration 52, inertia 2030.6971435546875
# Iteration 53, inertia 2030.6728515625
# Iteration 54, inertia 2030.6497802734375
# Iteration 55, inertia 2030.6287841796875
# Iteration 56, inertia 2030.6031494140625
# Iteration 57, inertia 2030.5809326171875
# Iteration 58, inertia 2030.5543212890625
# Iteration 59, inertia 2030.54638671875
# Iteration 60, inertia 2030.5360107421875
# Iteration 61, inertia 2030.528564453125
# Iteration 62, inertia 2030.5133056640625
# Iteration 63, inertia 2030.5059814453125
# Iteration 64, inertia 2030.5009765625
# Iteration 65, inertia 2030.49658203125
# Iteration 66, inertia 2030.489501953125
# Iteration 67, inertia 2030.484619140625
# Iteration 68, inertia 2030.47509765625
# Iteration 69, inertia 2030.468505859375
# Iteration 70, inertia 2030.4571533203125
# Iteration 71, inertia 2030.45703125
# Iteration 72, inertia 2030.4522705078125
# Iteration 73, inertia 2030.44580078125
# Iteration 74, inertia 2030.4383544921875
# Iteration 75, inertia 2030.4237060546875
# Iteration 76, inertia 2030.4100341796875
# Iteration 77, inertia 2030.3978271484375
# Iteration 78, inertia 2030.389404296875
# Iteration 79, inertia 2030.3807373046875
# Iteration 80, inertia 2030.373291015625
# Iteration 81, inertia 2030.3648681640625
# Iteration 82, inertia 2030.35498046875
# Iteration 83, inertia 2030.351318359375
# Iteration 84, inertia 2030.3460693359375
# Iteration 85, inertia 2030.332763671875
# Iteration 86, inertia 2030.3253173828125
# Iteration 87, inertia 2030.3238525390625
# Iteration 88, inertia 2030.3260498046875
# Iteration 89, inertia 2030.317626953125
# Iteration 90, inertia 2030.313720703125
# Iteration 91, inertia 2030.310546875
# Iteration 92, inertia 2030.311279296875
# Iteration 93, inertia 2030.304931640625
# Iteration 94, inertia 2030.304931640625
# Iteration 95, inertia 2030.3062744140625
# Iteration 96, inertia 2030.3067626953125
# Iteration 97, inertia 2030.307861328125
# Iteration 98, inertia 2030.30712890625
# Iteration 99, inertia 2030.3065185546875
# Iteration 100, inertia 2030.30615234375
# Iteration 101, inertia 2030.307861328125
# Iteration 102, inertia 2030.30517578125
# Iteration 103, inertia 2030.305908203125
# Iteration 104, inertia 2030.3055419921875
# Iteration 105, inertia 2030.306396484375
# Iteration 106, inertia 2030.3057861328125
# Iteration 107, inertia 2030.305419921875
# Iteration 108, inertia 2030.3057861328125
# Iteration 109, inertia 2030.304443359375
# Iteration 110, inertia 2030.3046875
# Iteration 111, inertia 2030.303466796875
# Iteration 112, inertia 2030.3028564453125
# Iteration 113, inertia 2030.30322265625
# Iteration 114, inertia 2030.298583984375
# Iteration 115, inertia 2030.2989501953125
# Iteration 116, inertia 2030.2989501953125
# Iteration 117, inertia 2030.296875
# Iteration 118, inertia 2030.2926025390625
# Iteration 119, inertia 2030.2918701171875
# Iteration 120, inertia 2030.2886962890625
# Iteration 121, inertia 2030.286376953125
# Iteration 122, inertia 2030.2843017578125
# Iteration 123, inertia 2030.2822265625
# Iteration 124, inertia 2030.2833251953125
# Iteration 125, inertia 2030.2830810546875
# Iteration 126, inertia 2030.2833251953125
# Iteration 127, inertia 2030.2823486328125
# Iteration 128, inertia 2030.28271484375
# Iteration 129, inertia 2030.280029296875
# Iteration 130, inertia 2030.277099609375
# Iteration 131, inertia 2030.274169921875
# Iteration 132, inertia 2030.2730712890625
# Iteration 133, inertia 2030.2708740234375
# Iteration 134, inertia 2030.2686767578125
# Iteration 135, inertia 2030.2640380859375
# Iteration 136, inertia 2030.2606201171875
# Iteration 137, inertia 2030.254150390625
# Iteration 138, inertia 2030.2486572265625
# Iteration 139, inertia 2030.2452392578125
# Iteration 140, inertia 2030.24267578125
# Iteration 141, inertia 2030.24365234375
# Iteration 142, inertia 2030.2430419921875
# Iteration 143, inertia 2030.2423095703125
# Iteration 144, inertia 2030.24267578125
# Iteration 145, inertia 2030.2369384765625
# Iteration 146, inertia 2030.2359619140625
# Iteration 147, inertia 2030.235107421875
# Converged at iteration 147: strict convergence.
# Initialization complete
# Iteration 0, inertia 2665.03466796875
# Iteration 1, inertia 2194.367431640625
# Iteration 2, inertia 2126.855224609375
# Iteration 3, inertia 2096.698486328125
# Iteration 4, inertia 2079.81884765625
# Iteration 5, inertia 2068.911865234375
# Iteration 6, inertia 2061.414306640625
# Iteration 7, inertia 2055.904541015625
# Iteration 8, inertia 2051.81787109375
# Iteration 9, inertia 2048.734619140625
# Iteration 10, inertia 2046.3221435546875
# Iteration 11, inertia 2044.413818359375
# Iteration 12, inertia 2042.9749755859375
# Iteration 13, inertia 2041.803955078125
# Iteration 14, inertia 2040.849609375
# Iteration 15, inertia 2040.119140625
# Iteration 16, inertia 2039.470947265625
# Iteration 17, inertia 2038.860595703125
# Iteration 18, inertia 2038.2828369140625
# Iteration 19, inertia 2037.712158203125
# Iteration 20, inertia 2037.1856689453125
# Iteration 21, inertia 2036.7310791015625
# Iteration 22, inertia 2036.3370361328125
# Iteration 23, inertia 2036.0146484375
# Iteration 24, inertia 2035.7249755859375
# Iteration 25, inertia 2035.4530029296875
# Iteration 26, inertia 2035.2254638671875
# Iteration 27, inertia 2035.0303955078125
# Iteration 28, inertia 2034.8297119140625
# Iteration 29, inertia 2034.671630859375
# Iteration 30, inertia 2034.5115966796875
# Iteration 31, inertia 2034.375244140625
# Iteration 32, inertia 2034.232666015625
# Iteration 33, inertia 2034.100830078125
# Iteration 34, inertia 2034.003662109375
# Iteration 35, inertia 2033.8880615234375
# Iteration 36, inertia 2033.7821044921875
# Iteration 37, inertia 2033.692138671875
# Iteration 38, inertia 2033.61474609375
# Iteration 39, inertia 2033.5491943359375
# Iteration 40, inertia 2033.494384765625
# Iteration 41, inertia 2033.44189453125
# Iteration 42, inertia 2033.4049072265625
# Iteration 43, inertia 2033.3616943359375
# Iteration 44, inertia 2033.3349609375
# Iteration 45, inertia 2033.2857666015625
# Iteration 46, inertia 2033.2437744140625
# Iteration 47, inertia 2033.207763671875
# Iteration 48, inertia 2033.165283203125
# Iteration 49, inertia 2033.142822265625
# Iteration 50, inertia 2033.123779296875
# Iteration 51, inertia 2033.07373046875
# Iteration 52, inertia 2033.0234375
# Iteration 53, inertia 2032.9910888671875
# Iteration 54, inertia 2032.929443359375
# Iteration 55, inertia 2032.8836669921875
# Iteration 56, inertia 2032.8250732421875
# Iteration 57, inertia 2032.774169921875
# Iteration 58, inertia 2032.713623046875
# Iteration 59, inertia 2032.6654052734375
# Iteration 60, inertia 2032.6376953125
# Iteration 61, inertia 2032.606201171875
# Iteration 62, inertia 2032.5802001953125
# Iteration 63, inertia 2032.548828125
# Iteration 64, inertia 2032.538330078125
# Iteration 65, inertia 2032.521240234375
# Iteration 66, inertia 2032.5137939453125
# Iteration 67, inertia 2032.5054931640625
# Iteration 68, inertia 2032.491455078125
# Iteration 69, inertia 2032.470947265625
# Iteration 70, inertia 2032.45751953125
# Iteration 71, inertia 2032.4351806640625
# Iteration 72, inertia 2032.41552734375
# Iteration 73, inertia 2032.4002685546875
# Iteration 74, inertia 2032.385498046875
# Iteration 75, inertia 2032.37744140625
# Iteration 76, inertia 2032.373291015625
# Iteration 77, inertia 2032.3668212890625
# Iteration 78, inertia 2032.356201171875
# Iteration 79, inertia 2032.339599609375
# Iteration 80, inertia 2032.3221435546875
# Iteration 81, inertia 2032.3187255859375
# Iteration 82, inertia 2032.303466796875
# Iteration 83, inertia 2032.2958984375
# Iteration 84, inertia 2032.2869873046875
# Iteration 85, inertia 2032.264404296875
# Iteration 86, inertia 2032.258056640625
# Iteration 87, inertia 2032.246826171875
# Iteration 88, inertia 2032.231201171875
# Iteration 89, inertia 2032.2109375
# Iteration 90, inertia 2032.1937255859375
# Iteration 91, inertia 2032.17529296875
# Iteration 92, inertia 2032.162109375
# Iteration 93, inertia 2032.142333984375
# Iteration 94, inertia 2032.1248779296875
# Iteration 95, inertia 2032.115966796875
# Iteration 96, inertia 2032.110107421875
# Iteration 97, inertia 2032.1011962890625
# Iteration 98, inertia 2032.0911865234375
# Iteration 99, inertia 2032.070556640625
# Iteration 100, inertia 2032.05712890625
# Iteration 101, inertia 2032.050537109375
# Iteration 102, inertia 2032.048583984375
# Iteration 103, inertia 2032.042724609375
# Iteration 104, inertia 2032.0445556640625
# Iteration 105, inertia 2032.040771484375
# Iteration 106, inertia 2032.0401611328125
# Iteration 107, inertia 2032.03662109375
# Iteration 108, inertia 2032.03125
# Iteration 109, inertia 2032.0330810546875
# Iteration 110, inertia 2032.0264892578125
# Iteration 111, inertia 2032.025146484375
# Iteration 112, inertia 2032.02392578125
# Iteration 113, inertia 2032.018310546875
# Iteration 114, inertia 2032.01025390625
# Iteration 115, inertia 2031.995361328125
# Iteration 116, inertia 2031.985107421875
# Iteration 117, inertia 2031.9761962890625
# Iteration 118, inertia 2031.9564208984375
# Iteration 119, inertia 2031.9366455078125
# Iteration 120, inertia 2031.9169921875
# Iteration 121, inertia 2031.904541015625
# Iteration 122, inertia 2031.8955078125
# Iteration 123, inertia 2031.887939453125
# Iteration 124, inertia 2031.8853759765625
# Iteration 125, inertia 2031.872802734375
# Iteration 126, inertia 2031.8638916015625
# Iteration 127, inertia 2031.8577880859375
# Iteration 128, inertia 2031.8521728515625
# Iteration 129, inertia 2031.849853515625
# Iteration 130, inertia 2031.846435546875
# Iteration 131, inertia 2031.8448486328125
# Iteration 132, inertia 2031.8438720703125
# Iteration 133, inertia 2031.842529296875
# Iteration 134, inertia 2031.8447265625
# Iteration 135, inertia 2031.843505859375
# Iteration 136, inertia 2031.8408203125
# Iteration 137, inertia 2031.84033203125
# Iteration 138, inertia 2031.8365478515625
# Iteration 139, inertia 2031.8363037109375
# Iteration 140, inertia 2031.83544921875
# Iteration 141, inertia 2031.8345947265625
# Iteration 142, inertia 2031.8350830078125
# Iteration 143, inertia 2031.8350830078125
# Converged at iteration 143: strict convergence.
# Initialization complete
# Iteration 0, inertia 2665.3193359375
# Iteration 1, inertia 2191.960693359375
# Iteration 2, inertia 2123.637939453125
# Iteration 3, inertia 2095.356689453125
# Iteration 4, inertia 2079.52587890625
# Iteration 5, inertia 2069.07177734375
# Iteration 6, inertia 2061.791259765625
# Iteration 7, inertia 2056.400146484375
# Iteration 8, inertia 2052.25
# Iteration 9, inertia 2048.98046875
# Iteration 10, inertia 2046.5025634765625
# Iteration 11, inertia 2044.5640869140625
# Iteration 12, inertia 2042.9849853515625
# Iteration 13, inertia 2041.5950927734375
# Iteration 14, inertia 2040.2694091796875
# Iteration 15, inertia 2039.2020263671875
# Iteration 16, inertia 2038.390869140625
# Iteration 17, inertia 2037.7677001953125
# Iteration 18, inertia 2037.22998046875
# Iteration 19, inertia 2036.7781982421875
# Iteration 20, inertia 2036.339111328125
# Iteration 21, inertia 2035.9013671875
# Iteration 22, inertia 2035.4912109375
# Iteration 23, inertia 2035.0858154296875
# Iteration 24, inertia 2034.7314453125
# Iteration 25, inertia 2034.353515625
# Iteration 26, inertia 2033.999267578125
# Iteration 27, inertia 2033.673583984375
# Iteration 28, inertia 2033.439453125
# Iteration 29, inertia 2033.2086181640625
# Iteration 30, inertia 2032.9822998046875
# Iteration 31, inertia 2032.833984375
# Iteration 32, inertia 2032.7069091796875
# Iteration 33, inertia 2032.593994140625
# Iteration 34, inertia 2032.4864501953125
# Iteration 35, inertia 2032.3712158203125
# Iteration 36, inertia 2032.2725830078125
# Iteration 37, inertia 2032.1572265625
# Iteration 38, inertia 2032.0469970703125
# Iteration 39, inertia 2031.940185546875
# Iteration 40, inertia 2031.8258056640625
# Iteration 41, inertia 2031.7186279296875
# Iteration 42, inertia 2031.6180419921875
# Iteration 43, inertia 2031.51123046875
# Iteration 44, inertia 2031.4132080078125
# Iteration 45, inertia 2031.3228759765625
# Iteration 46, inertia 2031.223876953125
# Iteration 47, inertia 2031.1148681640625
# Iteration 48, inertia 2031.002197265625
# Iteration 49, inertia 2030.8828125
# Iteration 50, inertia 2030.781494140625
# Iteration 51, inertia 2030.6761474609375
# Iteration 52, inertia 2030.5789794921875
# Iteration 53, inertia 2030.4852294921875
# Iteration 54, inertia 2030.3780517578125
# Iteration 55, inertia 2030.269775390625
# Iteration 56, inertia 2030.2103271484375
# Iteration 57, inertia 2030.1722412109375
# Iteration 58, inertia 2030.1004638671875
# Iteration 59, inertia 2030.005126953125
# Iteration 60, inertia 2029.9215087890625
# Iteration 61, inertia 2029.880615234375
# Iteration 62, inertia 2029.8404541015625
# Iteration 63, inertia 2029.8236083984375
# Iteration 64, inertia 2029.7994384765625
# Iteration 65, inertia 2029.7867431640625
# Iteration 66, inertia 2029.763427734375
# Iteration 67, inertia 2029.7440185546875
# Iteration 68, inertia 2029.7313232421875
# Iteration 69, inertia 2029.7227783203125
# Iteration 70, inertia 2029.711181640625
# Iteration 71, inertia 2029.6959228515625
# Iteration 72, inertia 2029.6910400390625
# Iteration 73, inertia 2029.6851806640625
# Iteration 74, inertia 2029.6805419921875
# Iteration 75, inertia 2029.66748046875
# Iteration 76, inertia 2029.662353515625
# Iteration 77, inertia 2029.6544189453125
# Iteration 78, inertia 2029.6455078125
# Iteration 79, inertia 2029.6407470703125
# Iteration 80, inertia 2029.638427734375
# Iteration 81, inertia 2029.6341552734375
# Iteration 82, inertia 2029.6239013671875
# Iteration 83, inertia 2029.6185302734375
# Iteration 84, inertia 2029.609619140625
# Iteration 85, inertia 2029.602783203125
# Iteration 86, inertia 2029.596435546875
# Iteration 87, inertia 2029.58740234375
# Iteration 88, inertia 2029.571044921875
# Iteration 89, inertia 2029.562255859375
# Iteration 90, inertia 2029.55029296875
# Iteration 91, inertia 2029.5496826171875
# Iteration 92, inertia 2029.546875
# Iteration 93, inertia 2029.5352783203125
# Iteration 94, inertia 2029.53271484375
# Iteration 95, inertia 2029.524658203125
# Iteration 96, inertia 2029.520751953125
# Iteration 97, inertia 2029.51416015625
# Iteration 98, inertia 2029.5054931640625
# Iteration 99, inertia 2029.5040283203125
# Iteration 100, inertia 2029.5023193359375
# Iteration 101, inertia 2029.501220703125
# Iteration 102, inertia 2029.501220703125
# Iteration 103, inertia 2029.5
# Iteration 104, inertia 2029.501708984375
# Iteration 105, inertia 2029.5
# Iteration 106, inertia 2029.49658203125
# Iteration 107, inertia 2029.4949951171875
# Iteration 108, inertia 2029.4952392578125
# Iteration 109, inertia 2029.4952392578125
# Iteration 110, inertia 2029.494140625
# Converged at iteration 110: strict convergence.

# %%
from collections import defaultdict
clusterImageIdMap = defaultdict(list)
totalCount = 0
for clusterId, image in zip(kmeans.labels_, allIndices):
    if len(clusterImageIdMap[clusterId]) < 17:
        clusterImageIdMap[clusterId].append(image)
        totalCount += 1
    if totalCount == 12800:
        print("Reached max limit")
        break
# Out:
# Reached max limit

# %%
kmeans.cluster_centers_
# Out:
# array([[4.2580566e-04, 5.9748301e-04, 5.5818297e-03, ..., 5.2689691e-05,
#         2.0025240e-04, 2.7144561e-03],
#        [1.3270357e-05, 2.6593683e-05, 4.3253647e-05, ..., 2.9688352e-05,
#         1.8629110e-03, 3.4080073e-04],
#        [1.6505823e-03, 4.7148514e-04, 9.9293201e-04, ..., 7.7215867e-04,
#         5.0312490e-05, 2.4045401e-03],
#        ...,
#        [2.5987683e-05, 7.5475611e-03, 2.3264412e-03, ..., 8.7153399e-05,
#         6.1658910e-05, 1.2810214e-04],
#        [1.2027473e-03, 8.2049519e-07, 1.0367716e-05, ..., 3.2855608e-03,
#         6.7136716e-07, 4.3596374e-06],
#        [3.1851232e-06, 2.9807896e-03, 1.9166067e-03, ..., 9.4703631e-05,
#         7.0744427e-05, 1.8749142e-04]], dtype=float32)

# %%
f = open("imageRequest-23.txt", "a")
for key in clusterImageIdMap:
    for image in clusterImageIdMap[key]:
        f.write(str(int(image)) + ".png\n")
f.close()

# %%
uniqueCheck = set()
for key in clusterImageIdMap:
    for image in clusterImageIdMap[key]:
        uniqueCheck.add(image)
len(uniqueCheck)
# Out:
# 12800
