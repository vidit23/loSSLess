# %%
from pathlib import Path
import argparse
import json
import math
import os
import random
import signal
import subprocess
import sys
import time

from PIL import Image, ImageOps, ImageFilter
from torch import nn, optim
import torch
import torchvision
import torchvision.transforms as transforms

import lightly
import lightly.models as models
import lightly.loss as loss
import lightly.data as data
from lightly.models.barlowtwins import BarlowTwins
from lightly.models.simclr import SimCLR

from simclr.modules.identity import Identity
import torch.nn.functional as F
from torchmetrics.functional import accuracy

from simclr.modules.transformations import TransformsSimCLR
from PIL import Image, ImageOps, ImageFilter

from tqdm import tqdm

import pytorch_lightning as pl
from pytorch_lightning import Trainer, LightningModule

import resnet

# %%
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, root, split, transform, limit=0):
        r"""
        Args:
            root: Location of the dataset folder, usually it is /dataset
            split: The split you want to used, it should be one of train, val or unlabeled.
            transform: the transform you want to applied to the images.
        """

        self.split = split
        self.transform = transform

        self.image_dir = os.path.join(root, split)
        label_path = os.path.join(root, f"{split}_label_tensor.pt")

        if limit == 0:
            self.num_images = len(os.listdir(self.image_dir))
        else:
            self.num_images = limit

        if os.path.exists(label_path):
            self.labels = torch.load(label_path)
        else:
            self.labels = -1 * torch.ones(self.num_images, dtype=torch.long)

    def __len__(self):
        return self.num_images

    def __getitem__(self, idx):
        idx = int(idx)
        with open(os.path.join(self.image_dir, f"{idx}.png"), 'rb') as f:
            img = Image.open(f).convert('RGB')
            
        if self.transform == None:
            return img, self.labels[idx]            

        return self.transform(img), self.labels[idx], torch.tensor(idx).float()

# %%
class ResNetClassifier(LightningModule):
    def __init__(self):
        super().__init__()
        self.backbone = torchvision.models.resnet34(zero_init_residual=True)
#         self.backbone = resnet.get_custom_resnet34()
        self.backbone.fc = nn.Identity()
#         self.backbone.load_state_dict(model.backbone.state_dict())
        
        self.lastLayer = torch.nn.Sequential(
            torch.nn.Linear(512, 1024),
            torch.nn.ReLU(),
            torch.nn.Linear(1024, 800),
        )
        
        for layer in self.lastLayer.modules():
           if isinstance(layer, nn.Linear):
                layer.weight.data.normal_(mean=0.0, std=0.01)
                layer.bias.data.zero_()
        
        self.param_groups = [dict(params=self.lastLayer.parameters(), lr=0.01)]
        self.param_groups.append(dict(params=self.backbone.parameters(), lr=0.0001))
        
        self.criterion=torch.nn.CrossEntropyLoss()
        
    def forward(self, x):
        x = self.backbone(x)
        x = self.lastLayer(x)
        return x
    
    def training_step(self, batch, batch_idx):
        data, label, _ = batch
        classProbs = self.forward(data)
        loss = self.criterion(classProbs, label)
        self.log('train_loss', loss)
        return loss
    
    def _evaluate(self, batch, batch_idx, stage=None):
        x, y, _ = batch
        out = self.forward(x)
        logits = F.log_softmax(out, dim=-1)
        loss = F.nll_loss(logits, y)
        preds = torch.argmax(logits, dim=-1)
        acc = accuracy(preds, y)

        if stage:
            self.log(f'{stage}_loss', loss, prog_bar=True)
            self.log(f'{stage}_acc', acc, prog_bar=True)

        return loss, acc
    
    def validation_step(self,batch,batch_idx):
        self._evaluate(batch, batch_idx, 'val')[0]
    
    def configure_optimizers(self):
        optimizer = optim.SGD(self.param_groups, 0, momentum=0.9, weight_decay=1e-5)
        scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, EPOCHS, verbose=True)
        return {'optimizer': optimizer, 'lr_scheduler': scheduler, 'monitor': 'val_loss'}

# %%
checkpointDir = 'barlow-34'

# %%
classifier = ResNetClassifier()

if os.path.isfile('/scratch/vvb238/' + checkpointDir + '/25-classifier.pth'):
    ckpt = torch.load('/scratch/vvb238/' + checkpointDir + '/25-classifier.pth',
                      map_location='cpu')
    classifier.load_state_dict(ckpt)

# %%
unlabeled_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

entireUnlabeledDataset = CustomDataset(root='/dataset', split="unlabeled", transform=unlabeled_transform)
# toBeRankedIndices = torch.tensor([i for i in range(len(entireUnlabeledDataset))])

# %%
classifier = classifier.cuda()
entireUnlabeledDataLoader = torch.utils.data.DataLoader(entireUnlabeledDataset, batch_size=512, 
                                                        shuffle=True, num_workers=4, pin_memory=True)

# %%
allDifferenceInTopTwo, predictedLabels = torch.Tensor(), torch.Tensor()
actualLabels, allIndices, allImageTensors = torch.Tensor(), torch.tensor([]), torch.Tensor()

classifier.eval()
print("\tStarting the evaluation process with unlabeled data")
with torch.no_grad():
    # Going through the left over unlabeled set and collecting the confidence for model predictions
    numOfBatches = len(entireUnlabeledDataset) / entireUnlabeledDataLoader.batch_size
    for idx, batch in tqdm(enumerate(entireUnlabeledDataLoader), total=int(numOfBatches)):
        images, labels, indices = batch

        images = images.cuda()
#             labels = labels.cuda()

        classScores = classifier(images)
        classLogits = F.softmax(classScores, dim=1)

        # Taking the top 2 values in the class prediction for each image
        labelConfidence, predictions = torch.sort(classLogits.data, dim=1, descending=True)
        # And subtracting those values
        differenceInTopTwo = labelConfidence[:, 0] - labelConfidence[:, 1]
        # Sorting based on the subtracted values, this gives the images with most confusion between top two classes
        sortedDifferenceInTopTwo, sortedDifferenceInTopTwoPos = torch.sort(differenceInTopTwo, descending=False)
        # Taking the top 150 of the confusion to avoid memory overload
        topSortedDifferenceInTopTwoPos = sortedDifferenceInTopTwoPos[:150]

        allDifferenceInTopTwo = torch.cat((allDifferenceInTopTwo, differenceInTopTwo[topSortedDifferenceInTopTwoPos].cpu()))
        allIndices = torch.cat((allIndices, indices[topSortedDifferenceInTopTwoPos].cpu()))
        

    print("\tGot the predictions of" , len(entireUnlabeledDataset), " images")

    # Sorting all the predictions based on the confidence scores and the argsort
    allSortedDifferenceInTopTwo, allSortedDifferenceInTopTwoPos = torch.sort(allDifferenceInTopTwo, descending=False)
    print("\tSorted the predictions based on confidence scores")

    # Calculating how many top predictions to retrain the model on
    leastDifferenceInTopTwoPos = allSortedDifferenceInTopTwoPos[:100000]
    print("\tGot the top ", 100000, "confidence indices")


    # Fetching the top confidence's index in original dataset
    topConfidenceIndices = allIndices[leastDifferenceInTopTwoPos]
# Out:
# 	Starting the evaluation process with unlabeled data
# 100%|██████████| 1000/1000 [05:44<00:00,  2.91it/s]
# 	Got the predictions of 512000  images
# 	Sorted the predictions based on confidence scores
# 	Got the top  100000 confidence indices

# %%
unlabeledFilteredData = torch.utils.data.Subset(entireUnlabeledDataset, topConfidenceIndices.tolist())
unlabeledFiteredDataLoader = torch.utils.data.DataLoader(unlabeledFilteredData, batch_size=512, shuffle=False, num_workers=4, pin_memory=True)

# %%
allIndices, allImageEncoding = torch.Tensor(), torch.tensor([])

classifier.eval()
print("\tStarting the evaluation process with unlabeled data")
with torch.no_grad():
    # Going through the left over unlabeled set and collecting the confidence for model predictions
    numOfBatches = len(unlabeledFilteredData) / unlabeledFiteredDataLoader.batch_size
    for idx, batch in tqdm(enumerate(unlabeledFiteredDataLoader), total=int(numOfBatches)):
        images, labels, indices = batch

        images = images.cuda()
#             labels = labels.cuda()

        classScores = classifier(images)
        classLogits = F.softmax(classScores, dim=1)

        allImageEncoding = torch.cat((allImageEncoding, classLogits.cpu()))
        allIndices = torch.cat((allIndices, indices.cpu()))
# Out:
# 	Starting the evaluation process with unlabeled data
# 196it [00:32,  5.95it/s]

# %%
from sklearn.cluster import KMeans
import numpy as np

# %%
allImageEncoding = allImageEncoding.numpy()
allIndices = allIndices.numpy()

# %%
allImageEncoding.shape
# Out:
# (100000, 800)

# %%
kmeans = KMeans(n_clusters=800, n_init=5, verbose=1).fit(allImageEncoding)
# Out:
# Initialization complete
# Iteration 0, inertia 3777.5068359375
# Iteration 1, inertia 3093.029052734375
# Iteration 2, inertia 2981.40283203125
# Iteration 3, inertia 2931.898193359375
# Iteration 4, inertia 2906.096435546875
# Iteration 5, inertia 2890.608642578125
# Iteration 6, inertia 2880.734375
# Iteration 7, inertia 2873.922607421875
# Iteration 8, inertia 2868.942138671875
# Iteration 9, inertia 2864.9873046875
# Iteration 10, inertia 2861.890869140625
# Iteration 11, inertia 2859.423583984375
# Iteration 12, inertia 2857.284912109375
# Iteration 13, inertia 2855.202392578125
# Iteration 14, inertia 2853.401611328125
# Iteration 15, inertia 2851.937744140625
# Iteration 16, inertia 2850.718994140625
# Iteration 17, inertia 2849.533935546875
# Iteration 18, inertia 2848.52294921875
# Iteration 19, inertia 2847.696533203125
# Iteration 20, inertia 2846.9404296875
# Iteration 21, inertia 2846.31787109375
# Iteration 22, inertia 2845.767822265625
# Iteration 23, inertia 2845.33154296875
# Iteration 24, inertia 2844.92431640625
# Iteration 25, inertia 2844.55859375
# Iteration 26, inertia 2844.205078125
# Iteration 27, inertia 2843.939453125
# Iteration 28, inertia 2843.7275390625
# Iteration 29, inertia 2843.5224609375
# Iteration 30, inertia 2843.2724609375
# Iteration 31, inertia 2842.97900390625
# Iteration 32, inertia 2842.705810546875
# Iteration 33, inertia 2842.45263671875
# Iteration 34, inertia 2842.183349609375
# Iteration 35, inertia 2841.900634765625
# Iteration 36, inertia 2841.657470703125
# Iteration 37, inertia 2841.47705078125
# Iteration 38, inertia 2841.30615234375
# Iteration 39, inertia 2841.1103515625
# Iteration 40, inertia 2840.79736328125
# Iteration 41, inertia 2840.458251953125
# Iteration 42, inertia 2840.146240234375
# Iteration 43, inertia 2839.9521484375
# Iteration 44, inertia 2839.8544921875
# Iteration 45, inertia 2839.728759765625
# Iteration 46, inertia 2839.6083984375
# Iteration 47, inertia 2839.496337890625
# Iteration 48, inertia 2839.384033203125
# Iteration 49, inertia 2839.2978515625
# Iteration 50, inertia 2839.229736328125
# Iteration 51, inertia 2839.15625
# Iteration 52, inertia 2839.117919921875
# Iteration 53, inertia 2839.06982421875
# Iteration 54, inertia 2839.034423828125
# Iteration 55, inertia 2838.996337890625
# Iteration 56, inertia 2838.960693359375
# Iteration 57, inertia 2838.9482421875
# Iteration 58, inertia 2838.915771484375
# Iteration 59, inertia 2838.892333984375
# Iteration 60, inertia 2838.87255859375
# Iteration 61, inertia 2838.847900390625
# Iteration 62, inertia 2838.830322265625
# Iteration 63, inertia 2838.821533203125
# Iteration 64, inertia 2838.810546875
# Iteration 65, inertia 2838.79345703125
# Iteration 66, inertia 2838.771484375
# Iteration 67, inertia 2838.745361328125
# Iteration 68, inertia 2838.71728515625
# Iteration 69, inertia 2838.689208984375
# Iteration 70, inertia 2838.672119140625
# Iteration 71, inertia 2838.650390625
# Iteration 72, inertia 2838.637939453125
# Iteration 73, inertia 2838.613525390625
# Iteration 74, inertia 2838.601318359375
# Iteration 75, inertia 2838.588134765625
# Iteration 76, inertia 2838.57666015625
# Iteration 77, inertia 2838.55810546875
# Iteration 78, inertia 2838.5498046875
# Iteration 79, inertia 2838.530517578125
# Iteration 80, inertia 2838.51806640625
# Iteration 81, inertia 2838.507080078125
# Iteration 82, inertia 2838.50732421875
# Iteration 83, inertia 2838.500244140625
# Iteration 84, inertia 2838.494140625
# Iteration 85, inertia 2838.480224609375
# Iteration 86, inertia 2838.45068359375
# Iteration 87, inertia 2838.42529296875
# Iteration 88, inertia 2838.40185546875
# Iteration 89, inertia 2838.388427734375
# Iteration 90, inertia 2838.364990234375
# Iteration 91, inertia 2838.3408203125
# Iteration 92, inertia 2838.32568359375
# Iteration 93, inertia 2838.30126953125
# Iteration 94, inertia 2838.2900390625
# Iteration 95, inertia 2838.259521484375
# Iteration 96, inertia 2838.230224609375
# Iteration 97, inertia 2838.19580078125
# Iteration 98, inertia 2838.17236328125
# Iteration 99, inertia 2838.140625
# Iteration 100, inertia 2838.12548828125
# Iteration 101, inertia 2838.109619140625
# Iteration 102, inertia 2838.091552734375
# Iteration 103, inertia 2838.0673828125
# Iteration 104, inertia 2838.04443359375
# Iteration 105, inertia 2838.014404296875
# Iteration 106, inertia 2837.9833984375
# Iteration 107, inertia 2837.96630859375
# Iteration 108, inertia 2837.943359375
# Iteration 109, inertia 2837.924072265625
# Iteration 110, inertia 2837.90234375
# Iteration 111, inertia 2837.896484375
# Iteration 112, inertia 2837.880859375
# Iteration 113, inertia 2837.864501953125
# Iteration 114, inertia 2837.8564453125
# Iteration 115, inertia 2837.85546875
# Iteration 116, inertia 2837.838134765625
# Iteration 117, inertia 2837.822021484375
# Iteration 118, inertia 2837.786865234375
# Iteration 119, inertia 2837.75439453125
# Iteration 120, inertia 2837.689453125
# Iteration 121, inertia 2837.647705078125
# Iteration 122, inertia 2837.630126953125
# Iteration 123, inertia 2837.591064453125
# Iteration 124, inertia 2837.55908203125
# Iteration 125, inertia 2837.5322265625
# Iteration 126, inertia 2837.53369140625
# Iteration 127, inertia 2837.5224609375
# Iteration 128, inertia 2837.511962890625
# Iteration 129, inertia 2837.5009765625
# Iteration 130, inertia 2837.492431640625
# Iteration 131, inertia 2837.486328125
# Iteration 132, inertia 2837.482666015625
# Iteration 133, inertia 2837.484130859375
# Iteration 134, inertia 2837.482421875
# Iteration 135, inertia 2837.481689453125
# Iteration 136, inertia 2837.48095703125
# Iteration 137, inertia 2837.47900390625
# Iteration 138, inertia 2837.477783203125
# Iteration 139, inertia 2837.47705078125
# Iteration 140, inertia 2837.4765625
# Iteration 141, inertia 2837.475830078125
# Iteration 142, inertia 2837.475830078125
# Iteration 143, inertia 2837.47509765625
# Iteration 144, inertia 2837.4736328125
# Iteration 145, inertia 2837.473876953125
# Iteration 146, inertia 2837.470947265625
# Iteration 147, inertia 2837.468017578125
# Iteration 148, inertia 2837.467041015625
# Converged at iteration 148: strict convergence.
# Initialization complete
# Iteration 0, inertia 3775.6845703125
# Iteration 1, inertia 3093.210693359375
# Iteration 2, inertia 2980.63134765625
# Iteration 3, inertia 2931.0341796875
# Iteration 4, inertia 2903.6181640625
# Iteration 5, inertia 2888.2509765625
# Iteration 6, inertia 2878.533203125
# Iteration 7, inertia 2871.47021484375
# Iteration 8, inertia 2866.170166015625
# Iteration 9, inertia 2862.080322265625
# Iteration 10, inertia 2858.870849609375
# Iteration 11, inertia 2856.39599609375
# Iteration 12, inertia 2854.265625
# Iteration 13, inertia 2852.3662109375
# Iteration 14, inertia 2850.904296875
# Iteration 15, inertia 2849.5546875
# Iteration 16, inertia 2848.445068359375
# Iteration 17, inertia 2847.50146484375
# Iteration 18, inertia 2846.658447265625
# Iteration 19, inertia 2845.996337890625
# Iteration 20, inertia 2845.446533203125
# Iteration 21, inertia 2845.007080078125
# Iteration 22, inertia 2844.623291015625
# Iteration 23, inertia 2844.281494140625
# Iteration 24, inertia 2843.9970703125
# Iteration 25, inertia 2843.750732421875
# Iteration 26, inertia 2843.490234375
# Iteration 27, inertia 2843.295166015625
# Iteration 28, inertia 2843.166015625
# Iteration 29, inertia 2843.03076171875
# Iteration 30, inertia 2842.892822265625
# Iteration 31, inertia 2842.804931640625
# Iteration 32, inertia 2842.722412109375
# Iteration 33, inertia 2842.63720703125
# Iteration 34, inertia 2842.56103515625
# Iteration 35, inertia 2842.51513671875
# Iteration 36, inertia 2842.4404296875
# Iteration 37, inertia 2842.3720703125
# Iteration 38, inertia 2842.295654296875
# Iteration 39, inertia 2842.212646484375
# Iteration 40, inertia 2842.134765625
# Iteration 41, inertia 2842.0654296875
# Iteration 42, inertia 2842.01416015625
# Iteration 43, inertia 2841.94921875
# Iteration 44, inertia 2841.891845703125
# Iteration 45, inertia 2841.8388671875
# Iteration 46, inertia 2841.796875
# Iteration 47, inertia 2841.749755859375
# Iteration 48, inertia 2841.7021484375
# Iteration 49, inertia 2841.671630859375
# Iteration 50, inertia 2841.625
# Iteration 51, inertia 2841.601318359375
# Iteration 52, inertia 2841.568115234375
# Iteration 53, inertia 2841.52734375
# Iteration 54, inertia 2841.4892578125
# Iteration 55, inertia 2841.4580078125
# Iteration 56, inertia 2841.441162109375
# Iteration 57, inertia 2841.41748046875
# Iteration 58, inertia 2841.373291015625
# Iteration 59, inertia 2841.343017578125
# Iteration 60, inertia 2841.321533203125
# Iteration 61, inertia 2841.309814453125
# Iteration 62, inertia 2841.296875
# Iteration 63, inertia 2841.28662109375
# Iteration 64, inertia 2841.282958984375
# Iteration 65, inertia 2841.27734375
# Iteration 66, inertia 2841.276123046875
# Iteration 67, inertia 2841.272216796875
# Iteration 68, inertia 2841.266357421875
# Iteration 69, inertia 2841.249267578125
# Iteration 70, inertia 2841.23095703125
# Iteration 71, inertia 2841.221923828125
# Iteration 72, inertia 2841.21630859375
# Iteration 73, inertia 2841.2099609375
# Iteration 74, inertia 2841.2080078125
# Iteration 75, inertia 2841.2021484375
# Iteration 76, inertia 2841.204833984375
# Iteration 77, inertia 2841.199462890625
# Iteration 78, inertia 2841.1962890625
# Iteration 79, inertia 2841.19287109375
# Iteration 80, inertia 2841.19287109375
# Iteration 81, inertia 2841.192626953125
# Converged at iteration 81: strict convergence.
# Initialization complete
# Iteration 0, inertia 3780.71435546875
# Iteration 1, inertia 3099.223388671875
# Iteration 2, inertia 2985.15185546875
# Iteration 3, inertia 2936.55712890625
# Iteration 4, inertia 2910.140380859375
# Iteration 5, inertia 2893.492431640625
# Iteration 6, inertia 2882.3251953125
# Iteration 7, inertia 2874.8955078125
# Iteration 8, inertia 2869.187744140625
# Iteration 9, inertia 2864.7509765625
# Iteration 10, inertia 2861.22900390625
# Iteration 11, inertia 2858.121826171875
# Iteration 12, inertia 2855.27685546875
# Iteration 13, inertia 2852.881103515625
# Iteration 14, inertia 2850.98046875
# Iteration 15, inertia 2849.557373046875
# Iteration 16, inertia 2848.36669921875
# Iteration 17, inertia 2847.35595703125
# Iteration 18, inertia 2846.50927734375
# Iteration 19, inertia 2845.830078125
# Iteration 20, inertia 2845.29345703125
# Iteration 21, inertia 2844.765625
# Iteration 22, inertia 2844.27197265625
# Iteration 23, inertia 2843.955322265625
# Iteration 24, inertia 2843.658203125
# Iteration 25, inertia 2843.33740234375
# Iteration 26, inertia 2843.036865234375
# Iteration 27, inertia 2842.787353515625
# Iteration 28, inertia 2842.537109375
# Iteration 29, inertia 2842.31884765625
# Iteration 30, inertia 2842.1318359375
# Iteration 31, inertia 2841.978515625
# Iteration 32, inertia 2841.80029296875
# Iteration 33, inertia 2841.61181640625
# Iteration 34, inertia 2841.402587890625
# Iteration 35, inertia 2841.20361328125
# Iteration 36, inertia 2841.025634765625
# Iteration 37, inertia 2840.88427734375
# Iteration 38, inertia 2840.75439453125
# Iteration 39, inertia 2840.6494140625
# Iteration 40, inertia 2840.53564453125
# Iteration 41, inertia 2840.40234375
# Iteration 42, inertia 2840.305419921875
# Iteration 43, inertia 2840.207275390625
# Iteration 44, inertia 2840.101318359375
# Iteration 45, inertia 2839.974609375
# Iteration 46, inertia 2839.896728515625
# Iteration 47, inertia 2839.82275390625
# Iteration 48, inertia 2839.724853515625
# Iteration 49, inertia 2839.64306640625
# Iteration 50, inertia 2839.5517578125
# Iteration 51, inertia 2839.4892578125
# Iteration 52, inertia 2839.4375
# Iteration 53, inertia 2839.39599609375
# Iteration 54, inertia 2839.348388671875
# Iteration 55, inertia 2839.279296875
# Iteration 56, inertia 2839.23291015625
# Iteration 57, inertia 2839.19287109375
# Iteration 58, inertia 2839.15478515625
# Iteration 59, inertia 2839.13818359375
# Iteration 60, inertia 2839.133056640625
# Iteration 61, inertia 2839.11669921875
# Iteration 62, inertia 2839.112060546875
# Iteration 63, inertia 2839.107666015625
# Iteration 64, inertia 2839.0966796875
# Iteration 65, inertia 2839.093505859375
# Iteration 66, inertia 2839.0908203125
# Iteration 67, inertia 2839.078857421875
# Iteration 68, inertia 2839.0498046875
# Iteration 69, inertia 2839.023193359375
# Iteration 70, inertia 2839.00634765625
# Iteration 71, inertia 2838.988037109375
# Iteration 72, inertia 2838.96875
# Iteration 73, inertia 2838.96337890625
# Iteration 74, inertia 2838.95703125
# Iteration 75, inertia 2838.947021484375
# Iteration 76, inertia 2838.940673828125
# Iteration 77, inertia 2838.926025390625
# Iteration 78, inertia 2838.914794921875
# Iteration 79, inertia 2838.9150390625
# Iteration 80, inertia 2838.90869140625
# Iteration 81, inertia 2838.90673828125
# Iteration 82, inertia 2838.902099609375
# Iteration 83, inertia 2838.902099609375
# Iteration 84, inertia 2838.89990234375
# Iteration 85, inertia 2838.89990234375
# Converged at iteration 85: strict convergence.
# Initialization complete
# Iteration 0, inertia 3804.083251953125
# Iteration 1, inertia 3096.68212890625
# Iteration 2, inertia 2985.648681640625
# Iteration 3, inertia 2938.62841796875
# Iteration 4, inertia 2912.33837890625
# Iteration 5, inertia 2895.685546875
# Iteration 6, inertia 2884.949951171875
# Iteration 7, inertia 2877.7939453125
# Iteration 8, inertia 2872.5302734375
# Iteration 9, inertia 2868.501708984375
# Iteration 10, inertia 2865.225341796875
# Iteration 11, inertia 2862.490234375
# Iteration 12, inertia 2860.329345703125
# Iteration 13, inertia 2858.591064453125
# Iteration 14, inertia 2857.09814453125
# Iteration 15, inertia 2855.756103515625
# Iteration 16, inertia 2854.669677734375
# Iteration 17, inertia 2853.70361328125
# Iteration 18, inertia 2852.955322265625
# Iteration 19, inertia 2852.29248046875
# Iteration 20, inertia 2851.78271484375
# Iteration 21, inertia 2851.29052734375
# Iteration 22, inertia 2850.806640625
# Iteration 23, inertia 2850.25
# Iteration 24, inertia 2849.841064453125
# Iteration 25, inertia 2849.4853515625
# Iteration 26, inertia 2849.185546875
# Iteration 27, inertia 2848.925537109375
# Iteration 28, inertia 2848.67529296875
# Iteration 29, inertia 2848.379150390625
# Iteration 30, inertia 2848.12548828125
# Iteration 31, inertia 2847.915771484375
# Iteration 32, inertia 2847.72607421875
# Iteration 33, inertia 2847.576416015625
# Iteration 34, inertia 2847.396728515625
# Iteration 35, inertia 2847.161376953125
# Iteration 36, inertia 2846.978759765625
# Iteration 37, inertia 2846.783203125
# Iteration 38, inertia 2846.581298828125
# Iteration 39, inertia 2846.400390625
# Iteration 40, inertia 2846.2783203125
# Iteration 41, inertia 2846.189208984375
# Iteration 42, inertia 2846.111328125
# Iteration 43, inertia 2846.052490234375
# Iteration 44, inertia 2846.011962890625
# Iteration 45, inertia 2845.978515625
# Iteration 46, inertia 2845.917724609375
# Iteration 47, inertia 2845.872802734375
# Iteration 48, inertia 2845.79541015625
# Iteration 49, inertia 2845.73876953125
# Iteration 50, inertia 2845.6884765625
# Iteration 51, inertia 2845.63232421875
# Iteration 52, inertia 2845.58544921875
# Iteration 53, inertia 2845.552734375
# Iteration 54, inertia 2845.51123046875
# Iteration 55, inertia 2845.483642578125
# Iteration 56, inertia 2845.439453125
# Iteration 57, inertia 2845.39013671875
# Iteration 58, inertia 2845.356201171875
# Iteration 59, inertia 2845.338623046875
# Iteration 60, inertia 2845.3212890625
# Iteration 61, inertia 2845.308837890625
# Iteration 62, inertia 2845.287841796875
# Iteration 63, inertia 2845.24658203125
# Iteration 64, inertia 2845.2314453125
# Iteration 65, inertia 2845.20849609375
# Iteration 66, inertia 2845.1650390625
# Iteration 67, inertia 2845.1064453125
# Iteration 68, inertia 2845.047607421875
# Iteration 69, inertia 2844.986328125
# Iteration 70, inertia 2844.93603515625
# Iteration 71, inertia 2844.868408203125
# Iteration 72, inertia 2844.83251953125
# Iteration 73, inertia 2844.8037109375
# Iteration 74, inertia 2844.78564453125
# Iteration 75, inertia 2844.759033203125
# Iteration 76, inertia 2844.7333984375
# Iteration 77, inertia 2844.717041015625
# Iteration 78, inertia 2844.684814453125
# Iteration 79, inertia 2844.666748046875
# Iteration 80, inertia 2844.634765625
# Iteration 81, inertia 2844.607421875
# Iteration 82, inertia 2844.58349609375
# Iteration 83, inertia 2844.564697265625
# Iteration 84, inertia 2844.5478515625
# Iteration 85, inertia 2844.525634765625
# Iteration 86, inertia 2844.50927734375
# Iteration 87, inertia 2844.48388671875
# Iteration 88, inertia 2844.443603515625
# Iteration 89, inertia 2844.408447265625
# Iteration 90, inertia 2844.37109375
# Iteration 91, inertia 2844.349853515625
# Iteration 92, inertia 2844.322021484375
# Iteration 93, inertia 2844.289794921875
# Iteration 94, inertia 2844.259765625
# Iteration 95, inertia 2844.2431640625
# Iteration 96, inertia 2844.229736328125
# Iteration 97, inertia 2844.20556640625
# Iteration 98, inertia 2844.18212890625
# Iteration 99, inertia 2844.15966796875
# Iteration 100, inertia 2844.13623046875
# Iteration 101, inertia 2844.1259765625
# Iteration 102, inertia 2844.1103515625
# Iteration 103, inertia 2844.10009765625
# Iteration 104, inertia 2844.09423828125
# Iteration 105, inertia 2844.088623046875
# Iteration 106, inertia 2844.088134765625
# Iteration 107, inertia 2844.085693359375
# Iteration 108, inertia 2844.0869140625
# Iteration 109, inertia 2844.08349609375
# Iteration 110, inertia 2844.070068359375
# Iteration 111, inertia 2844.06884765625
# Iteration 112, inertia 2844.064697265625
# Iteration 113, inertia 2844.05810546875
# Iteration 114, inertia 2844.05224609375
# Iteration 115, inertia 2844.040771484375
# Iteration 116, inertia 2844.03271484375
# Iteration 117, inertia 2844.019775390625
# Iteration 118, inertia 2844.01171875
# Iteration 119, inertia 2844.00390625
# Iteration 120, inertia 2843.9951171875
# Iteration 121, inertia 2843.99072265625
# Iteration 122, inertia 2843.987548828125
# Iteration 123, inertia 2843.972412109375
# Iteration 124, inertia 2843.97021484375
# Iteration 125, inertia 2843.962158203125
# Iteration 126, inertia 2843.966796875
# Iteration 127, inertia 2843.966796875
# Iteration 128, inertia 2843.962890625
# Iteration 129, inertia 2843.956787109375
# Iteration 130, inertia 2843.954833984375
# Iteration 131, inertia 2843.9541015625
# Iteration 132, inertia 2843.9521484375
# Iteration 133, inertia 2843.951171875
# Iteration 134, inertia 2843.95068359375
# Iteration 135, inertia 2843.94921875
# Iteration 136, inertia 2843.94384765625
# Iteration 137, inertia 2843.9462890625
# Iteration 138, inertia 2843.945068359375
# Iteration 139, inertia 2843.944091796875
# Iteration 140, inertia 2843.945556640625
# Iteration 141, inertia 2843.945556640625
# Converged at iteration 141: strict convergence.
# Initialization complete
# Iteration 0, inertia 3797.610595703125
# Iteration 1, inertia 3097.130126953125
# Iteration 2, inertia 2985.21533203125
# Iteration 3, inertia 2935.7314453125
# Iteration 4, inertia 2909.2080078125
# Iteration 5, inertia 2893.583984375
# Iteration 6, inertia 2883.595947265625
# Iteration 7, inertia 2877.041748046875
# Iteration 8, inertia 2871.95849609375
# Iteration 9, inertia 2867.7314453125
# Iteration 10, inertia 2864.494140625
# Iteration 11, inertia 2862.25048828125
# Iteration 12, inertia 2860.586181640625
# Iteration 13, inertia 2859.12451171875
# Iteration 14, inertia 2857.947265625
# Iteration 15, inertia 2856.788818359375
# Iteration 16, inertia 2855.79150390625
# Iteration 17, inertia 2854.969482421875
# Iteration 18, inertia 2854.176025390625
# Iteration 19, inertia 2853.407958984375
# Iteration 20, inertia 2852.667236328125
# Iteration 21, inertia 2851.935546875
# Iteration 22, inertia 2851.230712890625
# Iteration 23, inertia 2850.52587890625
# Iteration 24, inertia 2849.917724609375
# Iteration 25, inertia 2849.494140625
# Iteration 26, inertia 2849.0947265625
# Iteration 27, inertia 2848.727294921875
# Iteration 28, inertia 2848.370849609375
# Iteration 29, inertia 2848.002197265625
# Iteration 30, inertia 2847.68701171875
# Iteration 31, inertia 2847.443115234375
# Iteration 32, inertia 2847.20458984375
# Iteration 33, inertia 2847.04150390625
# Iteration 34, inertia 2846.849609375
# Iteration 35, inertia 2846.71533203125
# Iteration 36, inertia 2846.541015625
# Iteration 37, inertia 2846.40185546875
# Iteration 38, inertia 2846.271240234375
# Iteration 39, inertia 2846.12646484375
# Iteration 40, inertia 2845.97802734375
# Iteration 41, inertia 2845.87841796875
# Iteration 42, inertia 2845.760498046875
# Iteration 43, inertia 2845.654541015625
# Iteration 44, inertia 2845.5595703125
# Iteration 45, inertia 2845.464599609375
# Iteration 46, inertia 2845.32763671875
# Iteration 47, inertia 2845.19287109375
# Iteration 48, inertia 2845.05224609375
# Iteration 49, inertia 2844.942138671875
# Iteration 50, inertia 2844.860107421875
# Iteration 51, inertia 2844.777099609375
# Iteration 52, inertia 2844.7080078125
# Iteration 53, inertia 2844.6416015625
# Iteration 54, inertia 2844.5732421875
# Iteration 55, inertia 2844.5166015625
# Iteration 56, inertia 2844.463134765625
# Iteration 57, inertia 2844.40576171875
# Iteration 58, inertia 2844.35302734375
# Iteration 59, inertia 2844.290283203125
# Iteration 60, inertia 2844.240478515625
# Iteration 61, inertia 2844.184326171875
# Iteration 62, inertia 2844.13720703125
# Iteration 63, inertia 2844.078369140625
# Iteration 64, inertia 2844.05322265625
# Iteration 65, inertia 2844.00537109375
# Iteration 66, inertia 2843.95166015625
# Iteration 67, inertia 2843.9072265625
# Iteration 68, inertia 2843.8798828125
# Iteration 69, inertia 2843.84521484375
# Iteration 70, inertia 2843.81884765625
# Iteration 71, inertia 2843.79931640625
# Iteration 72, inertia 2843.77880859375
# Iteration 73, inertia 2843.760986328125
# Iteration 74, inertia 2843.735107421875
# Iteration 75, inertia 2843.703369140625
# Iteration 76, inertia 2843.661865234375
# Iteration 77, inertia 2843.6337890625
# Iteration 78, inertia 2843.603759765625
# Iteration 79, inertia 2843.5830078125
# Iteration 80, inertia 2843.5693359375
# Iteration 81, inertia 2843.561767578125
# Iteration 82, inertia 2843.55419921875
# Iteration 83, inertia 2843.543701171875
# Iteration 84, inertia 2843.5283203125
# Iteration 85, inertia 2843.499267578125
# Iteration 86, inertia 2843.480712890625
# Iteration 87, inertia 2843.456787109375
# Iteration 88, inertia 2843.4326171875
# Iteration 89, inertia 2843.415283203125
# Iteration 90, inertia 2843.39794921875
# Iteration 91, inertia 2843.390625
# Iteration 92, inertia 2843.38720703125
# Iteration 93, inertia 2843.380859375
# Iteration 94, inertia 2843.37646484375
# Iteration 95, inertia 2843.373779296875
# Iteration 96, inertia 2843.3720703125
# Iteration 97, inertia 2843.364990234375
# Iteration 98, inertia 2843.358642578125
# Iteration 99, inertia 2843.35693359375
# Converged at iteration 99: strict convergence.

# %%
from collections import defaultdict
clusterImageIdMap = defaultdict(list)
totalCount = 0
for clusterId, image in zip(kmeans.labels_, allIndices):
    if len(clusterImageIdMap[clusterId]) < 17:
        clusterImageIdMap[clusterId].append(image)
        totalCount += 1
    if totalCount == 12800:
        print("Reached max limit")
        break
# Out:
# Reached max limit

# %%
kmeans.cluster_centers_
# Out:
# array([[4.2580566e-04, 5.9748301e-04, 5.5818297e-03, ..., 5.2689691e-05,
#         2.0025240e-04, 2.7144561e-03],
#        [1.3270357e-05, 2.6593683e-05, 4.3253647e-05, ..., 2.9688352e-05,
#         1.8629110e-03, 3.4080073e-04],
#        [1.6505823e-03, 4.7148514e-04, 9.9293201e-04, ..., 7.7215867e-04,
#         5.0312490e-05, 2.4045401e-03],
#        ...,
#        [2.5987683e-05, 7.5475611e-03, 2.3264412e-03, ..., 8.7153399e-05,
#         6.1658910e-05, 1.2810214e-04],
#        [1.2027473e-03, 8.2049519e-07, 1.0367716e-05, ..., 3.2855608e-03,
#         6.7136716e-07, 4.3596374e-06],
#        [3.1851232e-06, 2.9807896e-03, 1.9166067e-03, ..., 9.4703631e-05,
#         7.0744427e-05, 1.8749142e-04]], dtype=float32)

# %%
f = open("imageRequest.txt", "a")
for key in clusterImageIdMap:
    for image in clusterImageIdMap[key]:
        f.write(str(int(image)) + ".png\n")
f.close()

# %%
uniqueCheck = set()
for key in clusterImageIdMap:
    for image in clusterImageIdMap[key]:
        uniqueCheck.add(image)
len(uniqueCheck)
# Out:
# 12800
